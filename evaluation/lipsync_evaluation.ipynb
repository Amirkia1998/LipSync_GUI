# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Copy the directory from drive to your colab files
# !cp -r drive/MyDrive/syncnet_python .
# Change to the work directory
# %cd syncnet_python

# %%
# Install requirements
# !pip install -r requirements.txt

# %%
# Install scescenedetect and check if you have the required version
# !pip install scenedetect==0.6.1
# !pip list

# %%
# Calculates the LSE-D and LSE-C scores for all the videos in the directory
# !sh calculate_scores_real_videos.sh videos/inner/
# Out:
# =================================== List of Input Files ===================================
# 1.	1_wav2lip.mp4
# 2.	3_wav2lip.mp4
# ...
#
#
#
#
# ####################################################################################################################
# ...
# ==================== File Under Process: 1_wav2lip.mp4 ============================================
# ...
# #########################################################################################################################
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
